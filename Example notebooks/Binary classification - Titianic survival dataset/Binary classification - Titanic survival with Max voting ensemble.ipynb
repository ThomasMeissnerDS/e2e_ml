# %% [markdown]
# # Titanic survival classification

# %%
# load libraries
from e2eml.classification import classification_blueprints as cb
from e2eml.full_processing.postprocessing import save_to_production, load_for_production
from e2eml.test.classification_blueprints_test import load_titanic_data
import pandas as pd
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import classification_report
import re
# Out:
# [nltk_data] Downloading package punkt to /home/thomas/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/thomas/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /home/thomas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/thomas/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Feature engineering
# Load & preprocess Titanic dataset. The feature engineering simulates the business knowledge part.
# The code has been taken from:
# https://towardsdatascience.com/predicting-the-survival-of-titanic-passengers-30870ccc7e8

# %%
# load Titianic data
test_df, test_target, val_df, val_df_target, test_categorical_cols = load_titanic_data()
# Out:
# Create additional features and modify existing ones.
# Do dataframe splits.

# %% [markdown]
# # Using e2eml - Run and save a pipeline
# We only need a few steps to get ur full pipeline:
# - Instantiate class
# - Run chosen blueprint
# - Save blueprint for later usage

# %%
# Instantiate class
titanic_auto_ml = cb.ClassificationBluePrint(datasource=test_df,
                                       target_variable=test_target,
                                       categorical_columns=test_categorical_cols,
                                       preferred_training_mode='auto',
                                       )
# Out:
# Ml task is binary
# Preferred training mode auto has been chosen. e2eml will automatically detect, if LGBM and Xgboost can use GPU acceleration and optimize the workflow accordingly.

# %%
# Run chosen blueprint
titanic_auto_ml.ml_special_multiclass_full_processing_multimodel_max_voting()
# Out:
# Started Execute test train split at 09:07:31.
# Started Apply datetime transformation at 09:07:31.
# Started Start Spacy, POS tagging at 09:07:31.
# Started PCA POS tags at 09:07:33.
# Started PCA POS tags at 09:07:35.
# Started PCA POS tags at 09:07:36.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 264 to 102
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      640 non-null    int64
#  1   Pclass           640 non-null    int64
#  2   Name             640 non-null    object
#  3   Sex              640 non-null    object
#  4   Age              640 non-null    int64
#  5   SibSp            640 non-null    int64
#  6   Parch            640 non-null    int64
#  7   Ticket           640 non-null    object
#  8   Fare             640 non-null    int64
#  9   Cabin            640 non-null    object
#  10  Embarked         639 non-null    object
#  11  Deck             640 non-null    int64
#  12  Title            640 non-null    int64
#  13  relatives        640 non-null    int64
#  14  not_alone        640 non-null    int64
#  15  Age_Class        640 non-null    int64
#  16  Fare_Per_Person  640 non-null    int64
#  17  POS PC-1 Name    517 non-null    float64
#  18  POS PC-2 Name    517 non-null    float64
#  19  POS PC-1 Ticket  517 non-null    float64
#  20  POS PC-2 Ticket  517 non-null    float64
#  21  POS PC-1 Cabin   517 non-null    float64
#  22  POS PC-2 Cabin   517 non-null    float64
# dtypes: float64(6), int64(12), object(5)
# memory usage: 140.0+ KB
# None
# Started PCA POS tags at 09:07:37.
# Started PCA POS tags at 09:07:37.
# Started PCA POS tags at 09:07:38.
# Started Handle rare features at 09:07:38.
# Started Remove cardinality at 09:07:38.
# Started Onehot + PCA categorical features at 09:07:38.
# Started Execute categorical encoding at 09:07:38.
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# Started  Delete columns with high share of NULLs at 09:07:39.
# Started Fill nulls at 09:07:39.
# Started Execute numerical binning at 09:07:39.
# Started Handle outliers at 09:07:39.
# Started Remove collinearity at 09:07:39.
# Started Execute clustering as a feature at 09:07:39.
# Started Scale data at 09:07:39.
# Started Execute clustering as a feature at 09:07:40.
# Started Execute clustering as a feature at 09:07:40.
# Started Execute clustering as a feature at 09:07:40.
# Started Execute clustering as a feature at 09:07:41.
# Started Execute clustering as a feature at 09:07:41.
# Started Execute clustering as a feature at 09:07:41.
# Started Execute clustering as a feature at 09:07:41.
# Started Execute clustering as a feature at 09:07:42.
# Started Select best features at 09:07:42.
# Features before selection are...PassengerId
# Features before selection are...Pclass
# Features before selection are...Sex
# Features before selection are...Age
# Features before selection are...SibSp
# Features before selection are...Parch
# Features before selection are...Fare
# Features before selection are...Embarked
# Features before selection are...Deck
# Features before selection are...Title
# Features before selection are...not_alone
# Features before selection are...Fare_Per_Person
# Features before selection are...POS PC-1 Name
# Features before selection are...POS PC-2 Name
# Features before selection are...POS PC-1 Ticket
# Features before selection are...POS PC-2 Ticket
# Features before selection are...POS PC-1 Cabin
# Features before selection are...POS PC-2 Cabin
# Features before selection are...PC-1_pca
# Features before selection are...PC-2_pca
# Features before selection are...isolation_probs
# Features before selection are...isolation_class
# Features before selection are...dbscan_cluster
# Features before selection are...kmeans_clusters2
# Features before selection are...kmeans_clusters3
# Features before selection are...kmeans_clusters4
# Features before selection are...kmeans_clusters5
# Features before selection are...kmeans_clusters6
# Features before selection are...kmeans_clusters7
# Features before selection are...kmeans_clusters8
# Features before selection are...kmeans_clusters9
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  1
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  2
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  3
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  4
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  5
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  6
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  7
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  8
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  9
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  1  iteration:  10
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  1
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  2
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  3
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  4
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  5
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  6
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  7
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  8
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  9
# [09:07:42] WARNING: /opt/conda/envs/rapids/conda-bld/xgboost_1623267594558/work/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Round:  2  iteration:  10
# BoostARoota ran successfully! Algorithm went through  2  rounds.
#  Selected features are... PassengerId.
#  Selected features are... Pclass.
#  Selected features are... Sex.
#  Selected features are... Age.
#  Selected features are... SibSp.
#  Selected features are... Parch.
#  Selected features are... Fare.
#  Selected features are... Embarked.
#  Selected features are... Deck.
#  Selected features are... Title.
#  Selected features are... Fare_Per_Person.
#  Selected features are... POS PC-1 Name.
#  Selected features are... POS PC-2 Name.
#  Selected features are... POS PC-1 Ticket.
#  Selected features are... POS PC-2 Ticket.
#  Selected features are... POS PC-1 Cabin.
#  Selected features are... PC-1_pca.
#  Selected features are... PC-2_pca.
#  Selected features are... isolation_probs.
#  Selected features are... kmeans_clusters4.
#  Selected features are... kmeans_clusters5.
#  Selected features are... kmeans_clusters6.
#  Selected features are... kmeans_clusters7.
#  Selected features are... kmeans_clusters8.
#  Selected features are... kmeans_clusters9.
# Found `num_iterations` in params. Will use it instead of argument
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [I 2021-08-12 09:07:42,967] A new study created in memory with name: no-name-c28af794-7846-4d92-8790-53148a2ae585
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:07:43,016] Trial 0 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 29892, 'lambda_l1': 395222.75469792425, 'lambda_l2': 49664.24475253092, 'num_leaves': 127, 'feature_fraction': 0.9344426036123397, 'bagging_freq': 6, 'min_child_samples': 57, 'learning_rate': 0.002100564907046995}. Best is trial 0 with value: 0.6915116123101234.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:07:43,053] Trial 1 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 21709, 'lambda_l1': 32786.43010699078, 'lambda_l2': 252.93583545422132, 'num_leaves': 78, 'feature_fraction': 0.49300151507840256, 'bagging_freq': 4, 'min_child_samples': 69, 'learning_rate': 3.563642459072756e-08}. Best is trial 0 with value: 0.6915116123101234.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:07:43,091] Trial 2 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 45736, 'lambda_l1': 115.6237292638926, 'lambda_l2': 931441.1718054863, 'num_leaves': 24, 'feature_fraction': 0.734573011180591, 'bagging_freq': 3, 'min_child_samples': 68, 'learning_rate': 2.3001423889689604e-08}. Best is trial 0 with value: 0.6915116123101234.
# Started Sort columns alphabetically at 09:07:42.
# Started Train LGBM at 09:07:42.
# Started Check LGBM for GPU acceleration. at 09:07:42.
# LGBM uses CPU.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:07:43,138] Trial 3 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 14589, 'lambda_l1': 371229.1625298273, 'lambda_l2': 29155.369244631725, 'num_leaves': 219, 'feature_fraction': 0.9105138681977872, 'bagging_freq': 6, 'min_child_samples': 14, 'learning_rate': 0.012814392677551061}. Best is trial 0 with value: 0.6915116123101234.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:07:43,289] Trial 4 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 3103, 'lambda_l1': 315253.4184171425, 'lambda_l2': 981.6363566303661, 'num_leaves': 190, 'feature_fraction': 0.49066838362338694, 'bagging_freq': 5, 'min_child_samples': 30, 'learning_rate': 7.598544676800736e-06}. Best is trial 0 with value: 0.6915116123101234.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,413] Trial 5 finished with value: 0.494513294076372 and parameters: {'num_boost_round': 15212, 'lambda_l1': 13.58255867176122, 'lambda_l2': 37.43591240897651, 'num_leaves': 212, 'feature_fraction': 0.6818583408178933, 'bagging_freq': 6, 'min_child_samples': 15, 'learning_rate': 0.0007377871928077313}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,462] Trial 6 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 18755, 'lambda_l1': 674785.7352712861, 'lambda_l2': 7924.74320100258, 'num_leaves': 226, 'feature_fraction': 0.8336359745342752, 'bagging_freq': 2, 'min_child_samples': 67, 'learning_rate': 0.00666915397552041}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,498] Trial 7 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,518] Trial 8 pruned. Trial was pruned at iteration 0.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,561] Trial 9 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 34686, 'lambda_l1': 313.7360799305969, 'lambda_l2': 122.37773157119292, 'num_leaves': 86, 'feature_fraction': 0.560524660579134, 'bagging_freq': 2, 'min_child_samples': 89, 'learning_rate': 1.8312982924281294e-08}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,660] Trial 10 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,715] Trial 11 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,765] Trial 12 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 10679, 'lambda_l1': 7365.93974378307, 'lambda_l2': 22.43720173231301, 'num_leaves': 107, 'feature_fraction': 0.6344485495951643, 'bagging_freq': 6, 'min_child_samples': 26, 'learning_rate': 0.06791891101411268}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,813] Trial 13 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,882] Trial 14 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 37027, 'lambda_l1': 3018.4645451428833, 'lambda_l2': 703078.8960085033, 'num_leaves': 130, 'feature_fraction': 0.7258510441363202, 'bagging_freq': 7, 'min_child_samples': 98, 'learning_rate': 1.9136545371517252e-05}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,933] Trial 15 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:25,986] Trial 16 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 10447, 'lambda_l1': 734.0949709755873, 'lambda_l2': 7.468070799696494, 'num_leaves': 102, 'feature_fraction': 0.9259189510610053, 'bagging_freq': 6, 'min_child_samples': 55, 'learning_rate': 2.9972747523611655e-06}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,036] Trial 17 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 6578, 'lambda_l1': 24824.115613017468, 'lambda_l2': 927.6583467231475, 'num_leaves': 250, 'feature_fraction': 0.766124485392257, 'bagging_freq': 5, 'min_child_samples': 16, 'learning_rate': 9.785313526120091e-05}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,075] Trial 18 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,137] Trial 19 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,192] Trial 20 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 25071, 'lambda_l1': 2498.086490057522, 'lambda_l2': 160860.26517751496, 'num_leaves': 191, 'feature_fraction': 0.9049677617665153, 'bagging_freq': 6, 'min_child_samples': 36, 'learning_rate': 0.0005245466445299858}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,243] Trial 21 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 6280, 'lambda_l1': 52443.602012041156, 'lambda_l2': 959.1620041592525, 'num_leaves': 251, 'feature_fraction': 0.7585253568974545, 'bagging_freq': 5, 'min_child_samples': 19, 'learning_rate': 0.00010354573660812888}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,291] Trial 22 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 9040, 'lambda_l1': 23113.318370805806, 'lambda_l2': 2031.2232708656145, 'num_leaves': 255, 'feature_fraction': 0.8212454564015693, 'bagging_freq': 5, 'min_child_samples': 5, 'learning_rate': 5.2311372660849134e-05}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,340] Trial 23 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 25903, 'lambda_l1': 1517.186609263312, 'lambda_l2': 132698.32861251672, 'num_leaves': 194, 'feature_fraction': 0.8906881981693315, 'bagging_freq': 6, 'min_child_samples': 40, 'learning_rate': 0.0006093711250948683}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,397] Trial 24 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 14539, 'lambda_l1': 96821.99622220786, 'lambda_l2': 523.5245166647861, 'num_leaves': 230, 'feature_fraction': 0.6057921854438914, 'bagging_freq': 4, 'min_child_samples': 19, 'learning_rate': 1.4183667837639123e-06}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,447] Trial 25 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 11846, 'lambda_l1': 9691.21516294571, 'lambda_l2': 9821.985571197542, 'num_leaves': 111, 'feature_fraction': 0.9615446035860237, 'bagging_freq': 5, 'min_child_samples': 10, 'learning_rate': 2.9175218213902813e-05}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,494] Trial 26 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,570] Trial 27 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 20811, 'lambda_l1': 10784.096616264258, 'lambda_l2': 4382.5969403776535, 'num_leaves': 166, 'feature_fraction': 0.8448019088005958, 'bagging_freq': 7, 'min_child_samples': 5, 'learning_rate': 0.00014208450768471624}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,626] Trial 28 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 14350, 'lambda_l1': 431.61893474677834, 'lambda_l2': 33943.16086048715, 'num_leaves': 115, 'feature_fraction': 0.9650763940607958, 'bagging_freq': 3, 'min_child_samples': 61, 'learning_rate': 1.8688887599556342e-05}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,686] Trial 29 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 20557, 'lambda_l1': 7663.453068818594, 'lambda_l2': 32635.825366732985, 'num_leaves': 78, 'feature_fraction': 0.9673729025307982, 'bagging_freq': 4, 'min_child_samples': 48, 'learning_rate': 5.702687000194765e-07}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,746] Trial 30 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 22178, 'lambda_l1': 64232.34714000867, 'lambda_l2': 4035.997640371042, 'num_leaves': 168, 'feature_fraction': 0.8582478526831212, 'bagging_freq': 7, 'min_child_samples': 24, 'learning_rate': 0.0047919197929676815}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,806] Trial 31 finished with value: 0.6915116123101233 and parameters: {'num_boost_round': 14962, 'lambda_l1': 406.3052301839294, 'lambda_l2': 40020.167866400705, 'num_leaves': 141, 'feature_fraction': 0.946620705653961, 'bagging_freq': 3, 'min_child_samples': 61, 'learning_rate': 0.0002329092312050639}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,861] Trial 32 finished with value: 0.6915116123101233 and parameters: {'num_boost_round': 15493, 'lambda_l1': 436.6692347320209, 'lambda_l2': 32111.136106587288, 'num_leaves': 74, 'feature_fraction': 0.9678740674453661, 'bagging_freq': 1, 'min_child_samples': 64, 'learning_rate': 2.4981313010105083e-07}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,904] Trial 33 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:26,949] Trial 34 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:27,002] Trial 35 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 6062, 'lambda_l1': 186.9020766338237, 'lambda_l2': 67733.73908459593, 'num_leaves': 5, 'feature_fraction': 0.5310868659953694, 'bagging_freq': 2, 'min_child_samples': 71, 'learning_rate': 0.028447768651952254}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:27,054] Trial 36 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:27,105] Trial 37 pruned. Trial was pruned at iteration 11.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:27,168] Trial 38 finished with value: 0.6915116123101234 and parameters: {'num_boost_round': 13784, 'lambda_l1': 971.0070688881782, 'lambda_l2': 37.43301254288028, 'num_leaves': 127, 'feature_fraction': 0.7950488982959324, 'bagging_freq': 1, 'min_child_samples': 71, 'learning_rate': 6.747502052302115e-06}. Best is trial 5 with value: 0.494513294076372.
# Found `num_boost_round` in params. Will use it instead of argument
# [I 2021-08-12 09:08:27,220] Trial 39 pruned. Trial was pruned at iteration 11.
# /home/thomas/anaconda3/envs/rapids-21.06/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning:
#
# Found `num_boost_round` in params. Will use it instead of argument
# [1]	train's binary_logloss: 0.667474	valid's binary_logloss: 0.661734
# Training until validation scores don't improve for 10 rounds
# [2]	train's binary_logloss: 0.667422	valid's binary_logloss: 0.661691
# [3]	train's binary_logloss: 0.667284	valid's binary_logloss: 0.661535
# [4]	train's binary_logloss: 0.667156	valid's binary_logloss: 0.661393
# [5]	train's binary_logloss: 0.667032	valid's binary_logloss: 0.661247
# [6]	train's binary_logloss: 0.66689	valid's binary_logloss: 0.661088
# [7]	train's binary_logloss: 0.666749	valid's binary_logloss: 0.660929
# [8]	train's binary_logloss: 0.666625	valid's binary_logloss: 0.660784
# [9]	train's binary_logloss: 0.666501	valid's binary_logloss: 0.660639
# [10]	train's binary_logloss: 0.666458	valid's binary_logloss: 0.660612
# [11]	train's binary_logloss: 0.666316	valid's binary_logloss: 0.660453
# [12]	train's binary_logloss: 0.666175	valid's binary_logloss: 0.660295
# [13]	train's binary_logloss: 0.666038	valid's binary_logloss: 0.66014
# [14]	train's binary_logloss: 0.665986	valid's binary_logloss: 0.660097
# [15]	train's binary_logloss: 0.665863	valid's binary_logloss: 0.659952
# [16]	train's binary_logloss: 0.665736	valid's binary_logloss: 0.659811
# [17]	train's binary_logloss: 0.665596	valid's binary_logloss: 0.659653
# [18]	train's binary_logloss: 0.665479	valid's binary_logloss: 0.659513
# [19]	train's binary_logloss: 0.665338	valid's binary_logloss: 0.659355
# [20]	train's binary_logloss: 0.665216	valid's binary_logloss: 0.659218
# [21]	train's binary_logloss: 0.665098	valid's binary_logloss: 0.65908
# [22]	train's binary_logloss: 0.664976	valid's binary_logloss: 0.658943
# [23]	train's binary_logloss: 0.664836	valid's binary_logloss: 0.658786
# [24]	train's binary_logloss: 0.664714	valid's binary_logloss: 0.658642
# [25]	train's binary_logloss: 0.664574	valid's binary_logloss: 0.658485
# [26]	train's binary_logloss: 0.664452	valid's binary_logloss: 0.658348
# [27]	train's binary_logloss: 0.66433	valid's binary_logloss: 0.658205
# [28]	train's binary_logloss: 0.664201	valid's binary_logloss: 0.658068
# [29]	train's binary_logloss: 0.664073	valid's binary_logloss: 0.657932
# [30]	train's binary_logloss: 0.663947	valid's binary_logloss: 0.657792
# [31]	train's binary_logloss: 0.663808	valid's binary_logloss: 0.657636
# [32]	train's binary_logloss: 0.663669	valid's binary_logloss: 0.65748
# [33]	train's binary_logloss: 0.663547	valid's binary_logloss: 0.657337
# [34]	train's binary_logloss: 0.663408	valid's binary_logloss: 0.657181
# [35]	train's binary_logloss: 0.663357	valid's binary_logloss: 0.657139
# [36]	train's binary_logloss: 0.663229	valid's binary_logloss: 0.657003
# [37]	train's binary_logloss: 0.663094	valid's binary_logloss: 0.65685
# [38]	train's binary_logloss: 0.662971	valid's binary_logloss: 0.656718
# [39]	train's binary_logloss: 0.662843	valid's binary_logloss: 0.656582
# [40]	train's binary_logloss: 0.662709	valid's binary_logloss: 0.65643
# [41]	train's binary_logloss: 0.662588	valid's binary_logloss: 0.656288
# [42]	train's binary_logloss: 0.662467	valid's binary_logloss: 0.656146
# [43]	train's binary_logloss: 0.662329	valid's binary_logloss: 0.655991
# [44]	train's binary_logloss: 0.66219	valid's binary_logloss: 0.655836
# [45]	train's binary_logloss: 0.662083	valid's binary_logloss: 0.655702
# [46]	train's binary_logloss: 0.662048	valid's binary_logloss: 0.655679
# [47]	train's binary_logloss: 0.66191	valid's binary_logloss: 0.655525
# [48]	train's binary_logloss: 0.661773	valid's binary_logloss: 0.65537
# [49]	train's binary_logloss: 0.661639	valid's binary_logloss: 0.655219
# [50]	train's binary_logloss: 0.661502	valid's binary_logloss: 0.655064
# [51]	train's binary_logloss: 0.661382	valid's binary_logloss: 0.654924
# [52]	train's binary_logloss: 0.661338	valid's binary_logloss: 0.654884
# [53]	train's binary_logloss: 0.661205	valid's binary_logloss: 0.654733
# [54]	train's binary_logloss: 0.661154	valid's binary_logloss: 0.654691
# [55]	train's binary_logloss: 0.661104	valid's binary_logloss: 0.65465
# [56]	train's binary_logloss: 0.660967	valid's binary_logloss: 0.654496
# [57]	train's binary_logloss: 0.66083	valid's binary_logloss: 0.654342
# [58]	train's binary_logloss: 0.660715	valid's binary_logloss: 0.654208
# [59]	train's binary_logloss: 0.660609	valid's binary_logloss: 0.654075
# [60]	train's binary_logloss: 0.660495	valid's binary_logloss: 0.653942
# [61]	train's binary_logloss: 0.660445	valid's binary_logloss: 0.6539
# [62]	train's binary_logloss: 0.660332	valid's binary_logloss: 0.653764
# [63]	train's binary_logloss: 0.660213	valid's binary_logloss: 0.653625
# [64]	train's binary_logloss: 0.660087	valid's binary_logloss: 0.653491
# [65]	train's binary_logloss: 0.659964	valid's binary_logloss: 0.653354
# [66]	train's binary_logloss: 0.659832	valid's binary_logloss: 0.653204
# [67]	train's binary_logloss: 0.659696	valid's binary_logloss: 0.653052
# [68]	train's binary_logloss: 0.65956	valid's binary_logloss: 0.652899
# [69]	train's binary_logloss: 0.659429	valid's binary_logloss: 0.65275
# [70]	train's binary_logloss: 0.659293	valid's binary_logloss: 0.652597
# [71]	train's binary_logloss: 0.659179	valid's binary_logloss: 0.652464
# [72]	train's binary_logloss: 0.659054	valid's binary_logloss: 0.652331
# [73]	train's binary_logloss: 0.658942	valid's binary_logloss: 0.652196
# [74]	train's binary_logloss: 0.658824	valid's binary_logloss: 0.652058
# [75]	train's binary_logloss: 0.658689	valid's binary_logloss: 0.651906
# [76]	train's binary_logloss: 0.658577	valid's binary_logloss: 0.651771
# [77]	train's binary_logloss: 0.658446	valid's binary_logloss: 0.651622
# [78]	train's binary_logloss: 0.658335	valid's binary_logloss: 0.651488
# [79]	train's binary_logloss: 0.6582	valid's binary_logloss: 0.651337
# [80]	train's binary_logloss: 0.658074	valid's binary_logloss: 0.651189
# [81]	train's binary_logloss: 0.657954	valid's binary_logloss: 0.65106
# [82]	train's binary_logloss: 0.657841	valid's binary_logloss: 0.650928
# [83]	train's binary_logloss: 0.657707	valid's binary_logloss: 0.650777
# [84]	train's binary_logloss: 0.657576	valid's binary_logloss: 0.650629
# [85]	train's binary_logloss: 0.657459	valid's binary_logloss: 0.650492
# [86]	train's binary_logloss: 0.657339	valid's binary_logloss: 0.650358
# [87]	train's binary_logloss: 0.657205	valid's binary_logloss: 0.650207
# [88]	train's binary_logloss: 0.657088	valid's binary_logloss: 0.65007
# [89]	train's binary_logloss: 0.656971	valid's binary_logloss: 0.649933
# [90]	train's binary_logloss: 0.656855	valid's binary_logloss: 0.649796
# [91]	train's binary_logloss: 0.656805	valid's binary_logloss: 0.649755
# [92]	train's binary_logloss: 0.656689	valid's binary_logloss: 0.649618
# [93]	train's binary_logloss: 0.656577	valid's binary_logloss: 0.649488
# [94]	train's binary_logloss: 0.656444	valid's binary_logloss: 0.649338
# [95]	train's binary_logloss: 0.65631	valid's binary_logloss: 0.649188
# [96]	train's binary_logloss: 0.656177	valid's binary_logloss: 0.649038
# [97]	train's binary_logloss: 0.656136	valid's binary_logloss: 0.649012
# [98]	train's binary_logloss: 0.656098	valid's binary_logloss: 0.648977
# [99]	train's binary_logloss: 0.655975	valid's binary_logloss: 0.648846
# [100]	train's binary_logloss: 0.655856	valid's binary_logloss: 0.648718
# [101]	train's binary_logloss: 0.655818	valid's binary_logloss: 0.648684
# [102]	train's binary_logloss: 0.655702	valid's binary_logloss: 0.648547
# [103]	train's binary_logloss: 0.65557	valid's binary_logloss: 0.648398
# [104]	train's binary_logloss: 0.655446	valid's binary_logloss: 0.648253
# [105]	train's binary_logloss: 0.655314	valid's binary_logloss: 0.648104
# [106]	train's binary_logloss: 0.655274	valid's binary_logloss: 0.648079
# [107]	train's binary_logloss: 0.655232	valid's binary_logloss: 0.648041
# [108]	train's binary_logloss: 0.655116	valid's binary_logloss: 0.647905
# [109]	train's binary_logloss: 0.655001	valid's binary_logloss: 0.64777
# [110]	train's binary_logloss: 0.654883	valid's binary_logloss: 0.647643
# [111]	train's binary_logloss: 0.654785	valid's binary_logloss: 0.64752
# [112]	train's binary_logloss: 0.654667	valid's binary_logloss: 0.647393
# [113]	train's binary_logloss: 0.654557	valid's binary_logloss: 0.647265
# [114]	train's binary_logloss: 0.654429	valid's binary_logloss: 0.64712
# [115]	train's binary_logloss: 0.654325	valid's binary_logloss: 0.646994
# [116]	train's binary_logloss: 0.654211	valid's binary_logloss: 0.646859
# [117]	train's binary_logloss: 0.654079	valid's binary_logloss: 0.646712
# [118]	train's binary_logloss: 0.653952	valid's binary_logloss: 0.646567
# [119]	train's binary_logloss: 0.65385	valid's binary_logloss: 0.646439
# [120]	train's binary_logloss: 0.653732	valid's binary_logloss: 0.646308
# [121]	train's binary_logloss: 0.65361	valid's binary_logloss: 0.646164
# [122]	train's binary_logloss: 0.653489	valid's binary_logloss: 0.646035
# [123]	train's binary_logloss: 0.653362	valid's binary_logloss: 0.645891
# [124]	train's binary_logloss: 0.653231	valid's binary_logloss: 0.645744
# [125]	train's binary_logloss: 0.65311	valid's binary_logloss: 0.645615
# [126]	train's binary_logloss: 0.652979	valid's binary_logloss: 0.645468
# [127]	train's binary_logloss: 0.652862	valid's binary_logloss: 0.645337
# [128]	train's binary_logloss: 0.652813	valid's binary_logloss: 0.645297
# [129]	train's binary_logloss: 0.652704	valid's binary_logloss: 0.645169
# [130]	train's binary_logloss: 0.652574	valid's binary_logloss: 0.645023
# [131]	train's binary_logloss: 0.652453	valid's binary_logloss: 0.64488
# [132]	train's binary_logloss: 0.652404	valid's binary_logloss: 0.64484
# [133]	train's binary_logloss: 0.652296	valid's binary_logloss: 0.644713
# [134]	train's binary_logloss: 0.652175	valid's binary_logloss: 0.644585
# [135]	train's binary_logloss: 0.652054	valid's binary_logloss: 0.644457
# [136]	train's binary_logloss: 0.652015	valid's binary_logloss: 0.644431
# [137]	train's binary_logloss: 0.651899	valid's binary_logloss: 0.644301
# [138]	train's binary_logloss: 0.651769	valid's binary_logloss: 0.644155
# [139]	train's binary_logloss: 0.651728	valid's binary_logloss: 0.644128
# [140]	train's binary_logloss: 0.651612	valid's binary_logloss: 0.644003
# [141]	train's binary_logloss: 0.651482	valid's binary_logloss: 0.643857
# [142]	train's binary_logloss: 0.651357	valid's binary_logloss: 0.643715
# [143]	train's binary_logloss: 0.65125	valid's binary_logloss: 0.643589
# [144]	train's binary_logloss: 0.65113	valid's binary_logloss: 0.643462
# [145]	train's binary_logloss: 0.651014	valid's binary_logloss: 0.643333
# [146]	train's binary_logloss: 0.650898	valid's binary_logloss: 0.643208
# [147]	train's binary_logloss: 0.650786	valid's binary_logloss: 0.643076
# [148]	train's binary_logloss: 0.650657	valid's binary_logloss: 0.642931
# [149]	train's binary_logloss: 0.650556	valid's binary_logloss: 0.642809
# [150]	train's binary_logloss: 0.650431	valid's binary_logloss: 0.642667
# [151]	train's binary_logloss: 0.650336	valid's binary_logloss: 0.642554
# [152]	train's binary_logloss: 0.650208	valid's binary_logloss: 0.642409
# [153]	train's binary_logloss: 0.650101	valid's binary_logloss: 0.642283
# [154]	train's binary_logloss: 0.650053	valid's binary_logloss: 0.642244
# [155]	train's binary_logloss: 0.649937	valid's binary_logloss: 0.64212
# [156]	train's binary_logloss: 0.649809	valid's binary_logloss: 0.641976
# [157]	train's binary_logloss: 0.64969	valid's binary_logloss: 0.64185
# [158]	train's binary_logloss: 0.649566	valid's binary_logloss: 0.641708
# [159]	train's binary_logloss: 0.649447	valid's binary_logloss: 0.641568
# [160]	train's binary_logloss: 0.64932	valid's binary_logloss: 0.641425
# [161]	train's binary_logloss: 0.649205	valid's binary_logloss: 0.641301
# [162]	train's binary_logloss: 0.649086	valid's binary_logloss: 0.641162
# [163]	train's binary_logloss: 0.64898	valid's binary_logloss: 0.641037
# [164]	train's binary_logloss: 0.648852	valid's binary_logloss: 0.640893
# [165]	train's binary_logloss: 0.648725	valid's binary_logloss: 0.64075
# [166]	train's binary_logloss: 0.648598	valid's binary_logloss: 0.640607
# [167]	train's binary_logloss: 0.648471	valid's binary_logloss: 0.640464
# [168]	train's binary_logloss: 0.648353	valid's binary_logloss: 0.640338
# [169]	train's binary_logloss: 0.648226	valid's binary_logloss: 0.640196
# [170]	train's binary_logloss: 0.64812	valid's binary_logloss: 0.640071
# [171]	train's binary_logloss: 0.64801	valid's binary_logloss: 0.639942
# [172]	train's binary_logloss: 0.647883	valid's binary_logloss: 0.639799
# [173]	train's binary_logloss: 0.647757	valid's binary_logloss: 0.639657
# [174]	train's binary_logloss: 0.647647	valid's binary_logloss: 0.639527
# [175]	train's binary_logloss: 0.647521	valid's binary_logloss: 0.639385
# [176]	train's binary_logloss: 0.647407	valid's binary_logloss: 0.639263
# [177]	train's binary_logloss: 0.6473	valid's binary_logloss: 0.639145
# [178]	train's binary_logloss: 0.647183	valid's binary_logloss: 0.639021
# [179]	train's binary_logloss: 0.647065	valid's binary_logloss: 0.638896
# [180]	train's binary_logloss: 0.646956	valid's binary_logloss: 0.638767
# [181]	train's binary_logloss: 0.64683	valid's binary_logloss: 0.638625
# [182]	train's binary_logloss: 0.646713	valid's binary_logloss: 0.638501
# [183]	train's binary_logloss: 0.646591	valid's binary_logloss: 0.638362
# [184]	train's binary_logloss: 0.646466	valid's binary_logloss: 0.638221
# [185]	train's binary_logloss: 0.646341	valid's binary_logloss: 0.63808
# [186]	train's binary_logloss: 0.646216	valid's binary_logloss: 0.637939
# [187]	train's binary_logloss: 0.646099	valid's binary_logloss: 0.637815
# [188]	train's binary_logloss: 0.645993	valid's binary_logloss: 0.637698
# [189]	train's binary_logloss: 0.645886	valid's binary_logloss: 0.637581
# [190]	train's binary_logloss: 0.645778	valid's binary_logloss: 0.637453
# [191]	train's binary_logloss: 0.645661	valid's binary_logloss: 0.63733
# [192]	train's binary_logloss: 0.645537	valid's binary_logloss: 0.637189
# [193]	train's binary_logloss: 0.645416	valid's binary_logloss: 0.637051
# [194]	train's binary_logloss: 0.645303	valid's binary_logloss: 0.636931
# [195]	train's binary_logloss: 0.645207	valid's binary_logloss: 0.63681
# [196]	train's binary_logloss: 0.645083	valid's binary_logloss: 0.63667
# [197]	train's binary_logloss: 0.644977	valid's binary_logloss: 0.636553
# [198]	train's binary_logloss: 0.644869	valid's binary_logloss: 0.636426
# [199]	train's binary_logloss: 0.644761	valid's binary_logloss: 0.636299
# [200]	train's binary_logloss: 0.644654	valid's binary_logloss: 0.636172
# [201]	train's binary_logloss: 0.644616	valid's binary_logloss: 0.636148
# [202]	train's binary_logloss: 0.644521	valid's binary_logloss: 0.636027
# [203]	train's binary_logloss: 0.644409	valid's binary_logloss: 0.635907
# [204]	train's binary_logloss: 0.644285	valid's binary_logloss: 0.635768
# [205]	train's binary_logloss: 0.644165	valid's binary_logloss: 0.635631
# [206]	train's binary_logloss: 0.64405	valid's binary_logloss: 0.635509
# [207]	train's binary_logloss: 0.643927	valid's binary_logloss: 0.635369
# [208]	train's binary_logloss: 0.643807	valid's binary_logloss: 0.635233
# [209]	train's binary_logloss: 0.643684	valid's binary_logloss: 0.635094
# [210]	train's binary_logloss: 0.64356	valid's binary_logloss: 0.634955
# [211]	train's binary_logloss: 0.643437	valid's binary_logloss: 0.634817
# [212]	train's binary_logloss: 0.643331	valid's binary_logloss: 0.63469
# [213]	train's binary_logloss: 0.643299	valid's binary_logloss: 0.634662
# [214]	train's binary_logloss: 0.643189	valid's binary_logloss: 0.634539
# [215]	train's binary_logloss: 0.643066	valid's binary_logloss: 0.6344
# [216]	train's binary_logloss: 0.642943	valid's binary_logloss: 0.634262
# [217]	train's binary_logloss: 0.642821	valid's binary_logloss: 0.634124
# [218]	train's binary_logloss: 0.642702	valid's binary_logloss: 0.633989
# [219]	train's binary_logloss: 0.642602	valid's binary_logloss: 0.633867
# [220]	train's binary_logloss: 0.642556	valid's binary_logloss: 0.633832
# [221]	train's binary_logloss: 0.642452	valid's binary_logloss: 0.633717
# [222]	train's binary_logloss: 0.642406	valid's binary_logloss: 0.633679
# [223]	train's binary_logloss: 0.642292	valid's binary_logloss: 0.633558
# [224]	train's binary_logloss: 0.642178	valid's binary_logloss: 0.633424
# [225]	train's binary_logloss: 0.642132	valid's binary_logloss: 0.633386
# [226]	train's binary_logloss: 0.64201	valid's binary_logloss: 0.633248
# [227]	train's binary_logloss: 0.641963	valid's binary_logloss: 0.63321
# [228]	train's binary_logloss: 0.64185	valid's binary_logloss: 0.633089
# [229]	train's binary_logloss: 0.641732	valid's binary_logloss: 0.632955
# [230]	train's binary_logloss: 0.641613	valid's binary_logloss: 0.63282
# [231]	train's binary_logloss: 0.641492	valid's binary_logloss: 0.632683
# [232]	train's binary_logloss: 0.641455	valid's binary_logloss: 0.632659
# [233]	train's binary_logloss: 0.641334	valid's binary_logloss: 0.632522
# [234]	train's binary_logloss: 0.641234	valid's binary_logloss: 0.632401
# [235]	train's binary_logloss: 0.641133	valid's binary_logloss: 0.632282
# [236]	train's binary_logloss: 0.641012	valid's binary_logloss: 0.632145
# [237]	train's binary_logloss: 0.640912	valid's binary_logloss: 0.632027
# [238]	train's binary_logloss: 0.640795	valid's binary_logloss: 0.631893
# [239]	train's binary_logloss: 0.640677	valid's binary_logloss: 0.63176
# [240]	train's binary_logloss: 0.640564	valid's binary_logloss: 0.63164
# [241]	train's binary_logloss: 0.64046	valid's binary_logloss: 0.631516
# [242]	train's binary_logloss: 0.640357	valid's binary_logloss: 0.631403
# [243]	train's binary_logloss: 0.640236	valid's binary_logloss: 0.631267
# [244]	train's binary_logloss: 0.640116	valid's binary_logloss: 0.631131
# [245]	train's binary_logloss: 0.639995	valid's binary_logloss: 0.630995
# [246]	train's binary_logloss: 0.639879	valid's binary_logloss: 0.630862
# [247]	train's binary_logloss: 0.639766	valid's binary_logloss: 0.630742
# [248]	train's binary_logloss: 0.639646	valid's binary_logloss: 0.630607
# [249]	train's binary_logloss: 0.639526	valid's binary_logloss: 0.630471
# [250]	train's binary_logloss: 0.639422	valid's binary_logloss: 0.630348
# [251]	train's binary_logloss: 0.639318	valid's binary_logloss: 0.630225
# [252]	train's binary_logloss: 0.639198	valid's binary_logloss: 0.63009
# [253]	train's binary_logloss: 0.639079	valid's binary_logloss: 0.629955
# [254]	train's binary_logloss: 0.638968	valid's binary_logloss: 0.629824
# [255]	train's binary_logloss: 0.638856	valid's binary_logloss: 0.629693
# [256]	train's binary_logloss: 0.638737	valid's binary_logloss: 0.629558
# [257]	train's binary_logloss: 0.638618	valid's binary_logloss: 0.629423
# [258]	train's binary_logloss: 0.638499	valid's binary_logloss: 0.629289
# [259]	train's binary_logloss: 0.63846	valid's binary_logloss: 0.629254
# [260]	train's binary_logloss: 0.638414	valid's binary_logloss: 0.629216
# [261]	train's binary_logloss: 0.638299	valid's binary_logloss: 0.629085
# [262]	train's binary_logloss: 0.638207	valid's binary_logloss: 0.628969
# [263]	train's binary_logloss: 0.638092	valid's binary_logloss: 0.628837
# [264]	train's binary_logloss: 0.637994	valid's binary_logloss: 0.628722
# [265]	train's binary_logloss: 0.637896	valid's binary_logloss: 0.628606
# [266]	train's binary_logloss: 0.63779	valid's binary_logloss: 0.628488
# [267]	train's binary_logloss: 0.637679	valid's binary_logloss: 0.62837
# [268]	train's binary_logloss: 0.637561	valid's binary_logloss: 0.628236
# [269]	train's binary_logloss: 0.637443	valid's binary_logloss: 0.628102
# [270]	train's binary_logloss: 0.637337	valid's binary_logloss: 0.627984
# [271]	train's binary_logloss: 0.637219	valid's binary_logloss: 0.62785
# [272]	train's binary_logloss: 0.637121	valid's binary_logloss: 0.627735
# [273]	train's binary_logloss: 0.63701	valid's binary_logloss: 0.627617
# [274]	train's binary_logloss: 0.636965	valid's binary_logloss: 0.62758
# [275]	train's binary_logloss: 0.636864	valid's binary_logloss: 0.627469
# [276]	train's binary_logloss: 0.636768	valid's binary_logloss: 0.627352
# [277]	train's binary_logloss: 0.63665	valid's binary_logloss: 0.627219
# [278]	train's binary_logloss: 0.63654	valid's binary_logloss: 0.627102
# [279]	train's binary_logloss: 0.636422	valid's binary_logloss: 0.626969
# [280]	train's binary_logloss: 0.63632	valid's binary_logloss: 0.626848
# [281]	train's binary_logloss: 0.636224	valid's binary_logloss: 0.626734
# [282]	train's binary_logloss: 0.636106	valid's binary_logloss: 0.626602
# [283]	train's binary_logloss: 0.636005	valid's binary_logloss: 0.626481
# [284]	train's binary_logloss: 0.635888	valid's binary_logloss: 0.626349
# [285]	train's binary_logloss: 0.635771	valid's binary_logloss: 0.626217
# ...
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# epoch 64 | loss: 0.89676 | val_0_logloss: 0.40934 |  0:01:02s
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# epoch 65 | loss: 0.88302 | val_0_logloss: 0.40935 |  0:01:03s
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# epoch 66 | loss: 0.8824  | val_0_logloss: 0.41038 |  0:01:04s
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# epoch 67 | loss: 0.89479 | val_0_logloss: 0.40866 |  0:01:05s
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# epoch 68 | loss: 0.89685 | val_0_logloss: 0.40795 |  0:01:06s
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# epoch 69 | loss: 0.88823 | val_0_logloss: 0.40989 |  0:01:07s
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# epoch 70 | loss: 0.9141  | val_0_logloss: 0.40896 |  0:01:08s
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_logloss = 0.36921
# Best weights from best epoch are automatically used!
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Started Predict with LGBM at 09:29:49.
# 09:29:49
# /home/thomas/anaconda3/envs/rapids-21.06/lib/python3.8/site-packages/sklearn/metrics/_classification.py:900: RuntimeWarning:
#
# invalid value encountered in double_scalars
# The ROC_AUC score is 0.8854166666666667
# The Matthew correlation is 0.7032737300610193
# -------------------
# The accuracy is 0.8625
# The recall is 0.8625
# The macro F1 score is 0.8476190476190476
# The micro F1 score is 0.8625
# The weighted F1 score is 0.8595238095238095
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.94      0.90       100
#          1.0       0.88      0.73      0.80        60
#
#     accuracy                           0.86       160
#    macro avg       0.87      0.84      0.85       160
# weighted avg       0.86      0.86      0.86       160
#
# Started Predict with Xgboost at 09:29:49.
# 09:29:49
# /home/thomas/anaconda3/envs/rapids-21.06/lib/python3.8/site-packages/sklearn/metrics/_classification.py:900: RuntimeWarning:
#
# invalid value encountered in double_scalars
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# The ROC_AUC score is 0.8913333333333333
# The Matthew correlation is 0.7032737300610193
# -------------------
# The accuracy is 0.8625
# The recall is 0.8625
# The macro F1 score is 0.8476190476190476
# The micro F1 score is 0.8625
# The weighted F1 score is 0.8595238095238095
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.94      0.90       100
#          1.0       0.88      0.73      0.80        60
#
#     accuracy                           0.86       160
#    macro avg       0.87      0.84      0.85       160
# weighted avg       0.86      0.86      0.86       160
#
# Started Predict with Vowpal Wabbit at 09:29:53.
# 09:29:53
# /home/thomas/anaconda3/envs/rapids-21.06/lib/python3.8/site-packages/sklearn/metrics/_classification.py:900: RuntimeWarning:
#
# invalid value encountered in double_scalars
# The ROC_AUC score is 0.8670000000000001
# The Matthew correlation is 0.5938574464184706
# -------------------
# The accuracy is 0.7875
# The recall is 0.7875
# The macro F1 score is 0.784126984126984
# The micro F1 score is 0.7875
# The weighted F1 score is 0.7908730158730158
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.73      0.81       100
#          1.0       0.66      0.88      0.76        60
#
#     accuracy                           0.79       160
#    macro avg       0.79      0.81      0.78       160
# weighted avg       0.82      0.79      0.79       160
#
# Started Predict with Tabnet classification at 09:29:55.
# 09:29:55
# /home/thomas/anaconda3/envs/rapids-21.06/lib/python3.8/site-packages/sklearn/metrics/_classification.py:900: RuntimeWarning:
#
# invalid value encountered in double_scalars
# The ROC_AUC score is 0.8969166666666666
# The Matthew correlation is 0.7059732072369208
# -------------------
# The accuracy is 0.8625
# The recall is 0.8625
# The macro F1 score is 0.8448245459354611
# The micro F1 score is 0.8625
# The weighted F1 score is 0.8579174748721565
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.96      0.90       100
#          1.0       0.91      0.70      0.79        60
#
#     accuracy                           0.86       160
#    macro avg       0.88      0.83      0.84       160
# weighted avg       0.87      0.86      0.86       160
#
# The Matthew correlation is 0.7032737300610193
# -------------------
# The accuracy is 0.8625
# The recall is 0.8625
# The macro F1 score is 0.8476190476190476
# The micro F1 score is 0.8625
# The weighted F1 score is 0.8595238095238095
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.94      0.90       100
#          1.0       0.88      0.73      0.80        60
#
#     accuracy                           0.86       160
#    macro avg       0.87      0.84      0.85       160
# weighted avg       0.86      0.86      0.86       160

# %%
# Save pipeline
save_to_production(titanic_auto_ml, file_name='titanic_automl_instance')

# %% [markdown]
# # Predict on new data
# In the beginning we kept a holdout dataset. We use this to simulate prediction on completely new data.

# %%
# load stored pipeline
titanic_auto_ml_loaded = load_for_production(file_name='titanic_automl_instance')

# %%
# predict on new data
titanic_auto_ml_loaded.ml_special_multiclass_full_processing_multimodel_max_voting(val_df)

# access predicted labels
val_y_hat = titanic_auto_ml_loaded.predicted_classes['max_voting']
# Out:
# Started Execute test train split at 09:29:57.
# Started Apply datetime transformation at 09:29:57.
# Started Start Spacy, POS tagging at 09:29:57.
# Started PCA POS tags at 09:29:57.
# Started PCA POS tags at 09:29:57.
# Started PCA POS tags at 09:29:58.
# Started Handle rare features at 09:29:58.
# Started Remove cardinality at 09:29:58.
# Started Onehot + PCA categorical features at 09:29:58.
# Started Execute categorical encoding at 09:29:58.
# Started  Delete columns with high share of NULLs at 09:29:58.
# Started Fill nulls at 09:29:58.
# Started Execute numerical binning at 09:29:58.
# Started Handle outliers at 09:29:58.
# Started Remove collinearity at 09:29:58.
# Started Execute clustering as a feature at 09:29:58.
# Started Execute clustering as a feature at 09:29:58.
# Started Execute clustering as a feature at 09:29:58.
# Started Execute clustering as a feature at 09:29:58.
# Started Execute clustering as a feature at 09:29:58.
# Started Execute clustering as a feature at 09:29:58.
# Started Execute clustering as a feature at 09:29:58.
# Started Execute clustering as a feature at 09:29:59.
# Started Execute clustering as a feature at 09:29:59.
# Started Select best features at 09:29:59.
# Started Sort columns alphabetically at 09:29:59.
# Started Predict with LGBM at 09:29:59.
# Started Predict with Xgboost at 09:29:59.
# Started Predict with Vowpal Wabbit at 09:29:59.
# Started Predict with Tabnet classification at 09:29:59.

# %%
# Assess prediction quality on holdout data
print(classification_report(val_df_target, val_y_hat))
try:
    matthews = matthews_corrcoef(val_df_target, val_y_hat)
except Exception:
    print("Matthew failed.")
    matthews = 0
print(matthews)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88        57
#            1       0.95      0.59      0.73        34
#
#     accuracy                           0.84        91
#    macro avg       0.88      0.79      0.80        91
# weighted avg       0.86      0.84      0.82        91
#
# 0.6552689256946953

# %%
# predictions from individual models can still be accessed:
y_hat_tabnet = titanic_auto_ml_loaded.predicted_classes['tabnet']

print(classification_report(val_df_target, y_hat_tabnet))
try:
    matthews = matthews_corrcoef(val_df_target, y_hat_tabnet)
except Exception:
    print("Matthew failed.")
    matthews = 0
print(matthews)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90        57
#            1       0.87      0.76      0.81        34
#
#     accuracy                           0.87        91
#    macro avg       0.87      0.85      0.86        91
# weighted avg       0.87      0.87      0.87        91
#
# 0.7147310156639431
